# %% [markdown]
# Imported Data for Polo Ralph Lauren from Drive

# %%
#=======INPUT LOCATION LAT/LONG=======#
Location = (-22.815,-43.2445)

#=======INPUT PATH TO DATAFRAME FILE=======#
pandas_file = '/gdrive/Shared drives/INF560/Code/Data Files/Dataframes/data4-PoloRalphLauren.csv'

#=======OUTPUT FILE PATH=======#
output_file = '/gdrive/Shared drives/INF560/Code/Code Files/pickles/loc4model.pkl'

import pandas as pd
df=pd.read_excel(pandas_file)

# %%
df.head(5)
# Out:
#    Unnamed: 0    0        1                  2                            3
# 0           0  5.0  Level 3  08:8c:2c:ee:f5:e2  2019-12-24 18:52:36.295 UTC
# 1           1  5.0  Level 3  40:26:19:a9:8f:79   2019-12-26 23:05:41.27 UTC
# 2           2  5.0  Level 3  28:83:35:28:74:53   2019-12-04 17:57:09.21 UTC
# 3           3  5.0  Level 3  7c:5c:f8:59:c1:44  2019-12-20 08:05:47.507 UTC
# 4           4  5.0  Level 3  5a:e5:45:23:ef:43  2019-12-12 14:45:18.495 UTC

# %%
df = df.drop('Unnamed: 0', 1)

# %%
df
# Out:
#         0        1                  2                            3
# 0     5.0  Level 3  08:8c:2c:ee:f5:e2  2019-12-24 18:52:36.295 UTC
# 1     5.0  Level 3  40:26:19:a9:8f:79   2019-12-26 23:05:41.27 UTC
# 2     5.0  Level 3  28:83:35:28:74:53   2019-12-04 17:57:09.21 UTC
# 3     5.0  Level 3  7c:5c:f8:59:c1:44  2019-12-20 08:05:47.507 UTC
# 4     5.0  Level 3  5a:e5:45:23:ef:43  2019-12-12 14:45:18.495 UTC
# ...   ...      ...                ...                          ...
# 7015  5.0  Level 3  8c:f5:a3:b3:b1:e1  2019-12-04 22:57:11.285 UTC
# 7016  5.0  Level 3  3a:a6:a2:8f:60:40  2019-12-06 00:51:10.373 UTC
# 7017  5.0  Level 3  dc:bf:e9:42:09:7e  2019-12-14 19:41:23.487 UTC
# 7018  5.0  Level 3  cc:c0:79:4c:39:13  2019-12-10 19:53:43.135 UTC
# 7019  5.0  Level 3  7c:8b:b5:c8:ab:17  2019-12-30 03:55:21.305 UTC
#
# [7020 rows x 4 columns]

# %%
df.columns = ['Ratings', 'level','MAC-ID','Timestamp']

# %%
df
# Out:
#       Ratings    level             MAC-ID                    Timestamp
# 0         5.0  Level 3  08:8c:2c:ee:f5:e2  2019-12-24 18:52:36.295 UTC
# 1         5.0  Level 3  40:26:19:a9:8f:79   2019-12-26 23:05:41.27 UTC
# 2         5.0  Level 3  28:83:35:28:74:53   2019-12-04 17:57:09.21 UTC
# 3         5.0  Level 3  7c:5c:f8:59:c1:44  2019-12-20 08:05:47.507 UTC
# 4         5.0  Level 3  5a:e5:45:23:ef:43  2019-12-12 14:45:18.495 UTC
# ...       ...      ...                ...                          ...
# 7015      5.0  Level 3  8c:f5:a3:b3:b1:e1  2019-12-04 22:57:11.285 UTC
# 7016      5.0  Level 3  3a:a6:a2:8f:60:40  2019-12-06 00:51:10.373 UTC
# 7017      5.0  Level 3  dc:bf:e9:42:09:7e  2019-12-14 19:41:23.487 UTC
# 7018      5.0  Level 3  cc:c0:79:4c:39:13  2019-12-10 19:53:43.135 UTC
# 7019      5.0  Level 3  7c:8b:b5:c8:ab:17  2019-12-30 03:55:21.305 UTC
#
# [7020 rows x 4 columns]

# %% [markdown]
# Formatted the Timestamps into dateTime types from string

# %%
df['Timestamp'] = df['Timestamp'].str.replace(r'UTC', '')

# %%
df.head(5)
# Out:
#    Ratings    level             MAC-ID                 Timestamp
# 0      5.0  Level 3  08:8c:2c:ee:f5:e2  2019-12-24 18:52:36.295
# 1      5.0  Level 3  40:26:19:a9:8f:79   2019-12-26 23:05:41.27
# 2      5.0  Level 3  28:83:35:28:74:53   2019-12-04 17:57:09.21
# 3      5.0  Level 3  7c:5c:f8:59:c1:44  2019-12-20 08:05:47.507
# 4      5.0  Level 3  5a:e5:45:23:ef:43  2019-12-12 14:45:18.495

# %%
df['Timestamp']=pd.to_datetime(df['Timestamp'])

# %%
df1=df

# %%
df1.head(5)
# Out:
#    Ratings    level             MAC-ID               Timestamp
# 0      5.0  Level 3  08:8c:2c:ee:f5:e2 2019-12-24 18:52:36.295
# 1      5.0  Level 3  40:26:19:a9:8f:79 2019-12-26 23:05:41.270
# 2      5.0  Level 3  28:83:35:28:74:53 2019-12-04 17:57:09.210
# 3      5.0  Level 3  7c:5c:f8:59:c1:44 2019-12-20 08:05:47.507
# 4      5.0  Level 3  5a:e5:45:23:ef:43 2019-12-12 14:45:18.495

# %% [markdown]
# Grouped the data by the MAC ID and sorted by Timestamp . This was done to extract consecutive wait times between 2 timestamps which is indicative of the time duration for which a user has been around this location .

# %%
df1=df1.sort_values('Timestamp', ascending=True)

# %%
df1.head(5)
# Out:
#       Ratings    level             MAC-ID               Timestamp
# 3730      5.0  Level 3  1a:1c:0b:df:1d:ad 2019-12-01 00:02:30.193
# 2546      5.0  Level 3  7c:5c:f8:45:2f:72 2019-12-01 00:13:19.203
# 1625      5.0  Level 3  60:1d:91:95:f6:ef 2019-12-01 00:38:21.454
# 2506      5.0  Level 3  7c:5c:f8:45:a9:f7 2019-12-01 00:53:28.129
# 1416      5.0  Level 3  7c:5c:f8:45:2f:72 2019-12-01 01:00:20.207

# %% [markdown]
# Computed the wait-time in seconds

# %%
df1['Wait-Time']=df1['Timestamp'].diff().astype('timedelta64[s]')

# %%
df1['Wait-Time'].fillna((df1['Wait-Time'].mean()), inplace=True)

# %%
df1.head(50)
# Out:
#       Ratings    level             MAC-ID               Timestamp    Wait-Time
# 3730      5.0  Level 3  1a:1c:0b:df:1d:ad 2019-12-01 00:02:30.193   368.765636
# 2546      5.0  Level 3  7c:5c:f8:45:2f:72 2019-12-01 00:13:19.203   649.000000
# 1625      5.0  Level 3  60:1d:91:95:f6:ef 2019-12-01 00:38:21.454  1502.000000
# 2506      5.0  Level 3  7c:5c:f8:45:a9:f7 2019-12-01 00:53:28.129   906.000000
# 1416      5.0  Level 3  7c:5c:f8:45:2f:72 2019-12-01 01:00:20.207   412.000000
# 4561      5.0  Level 3  7c:5c:f8:45:2f:72 2019-12-01 01:19:27.187  1146.000000
# 5991      5.0  Level 3  7c:8b:b5:c8:62:c7 2019-12-01 01:43:01.323  1414.000000
# 1690      5.0  Level 3  7c:5c:f8:45:a9:f7 2019-12-01 01:43:58.231    56.000000
# 5883      5.0  Level 3  a8:16:d0:47:65:3f 2019-12-01 01:49:42.316   344.000000
# 1555      5.0  Level 3  a8:16:d0:47:65:3f 2019-12-01 01:50:32.319    50.000000
# 2239      5.0  Level 3  7c:5c:f8:45:a9:f7 2019-12-01 04:15:09.248  8676.000000
# 6834      5.0  Level 3  7c:5c:f8:45:2f:72 2019-12-01 05:57:40.095  6150.000000
# 6851      5.0  Level 3  7c:5c:f8:45:2f:72 2019-12-01 05:57:40.119     0.000000
# 3464      5.0  Level 3  30:4b:07:33:3f:8f 2019-12-01 06:04:11.428   391.000000
# 3385      5.0  Level 3  7c:5c:f8:45:2f:72 2019-12-01 06:10:10.711   359.000000
# 6225      5.0  Level 3  38:9a:f6:d2:1f:6f 2019-12-01 06:35:20.265  1509.000000
# 6169      5.0  Level 3  38:9a:f6:d2:1f:6f 2019-12-01 06:35:20.266     0.000000
# 1580      5.0  Level 3  38:9a:f6:d2:1f:6f 2019-12-01 06:35:30.289    10.000000
# 4226      5.0  Level 3  7c:5c:f8:45:2f:72 2019-12-01 06:36:27.397    57.000000
# 3791      5.0  Level 3  38:9a:f6:d2:1f:6f 2019-12-01 06:49:58.373   810.000000
# 1581      5.0  Level 3  38:9a:f6:d2:1f:6f 2019-12-01 06:50:31.285    32.000000
# 4397      5.0  Level 3  38:9a:f6:d2:1f:6f 2019-12-01 06:51:53.228    81.000000
# 3320      5.0  Level 3  38:9a:f6:d2:1f:6f 2019-12-01 06:52:54.282    61.000000
# 1101      5.0  Level 3  38:9a:f6:d2:1f:6f 2019-12-01 06:59:35.103   400.000000
# 4074      5.0  Level 3  70:fd:46:3f:96:d2 2019-12-01 07:15:08.299   933.000000
# 6403      5.0  Level 3  7c:5c:f8:59:c1:44 2019-12-01 07:23:49.843   521.000000
# 5375      5.0  Level 3  7c:5c:f8:59:c1:44 2019-12-01 07:24:50.210    60.000000
# 1548      5.0  Level 3  e0:dc:ff:25:8d:9a 2019-12-01 07:44:18.604  1168.000000
# 4405      5.0  Level 3  7a:26:94:7b:86:5d 2019-12-01 08:10:20.696  1562.000000
# 526       5.0  Level 3  dc:bf:e9:42:f9:7e 2019-12-01 08:18:54.924   514.000000
# 487       5.0  Level 3  dc:bf:e9:42:f9:7e 2019-12-01 08:18:54.925     0.000000
# 5278      5.0  Level 3  1a:0b:28:1f:71:b8 2019-12-01 08:32:45.102   830.000000
# 4562      5.0  Level 3  f4:09:d8:18:99:c7 2019-12-01 08:51:11.552  1106.000000
# 4728      5.0  Level 3  fc:64:3a:75:e9:16 2019-12-01 09:06:28.982   917.000000
# 2430      5.0  Level 3  fc:64:3a:75:e9:16 2019-12-01 09:08:06.364    97.000000
# 3667      5.0  Level 3  80:58:f8:ec:a9:b0 2019-12-01 09:10:38.774   152.000000
# 3635      5.0  Level 3  80:58:f8:ec:a9:b0 2019-12-01 09:10:38.775     0.000000
# 3086      5.0  Level 3  f8:62:14:f0:e4:84 2019-12-01 09:23:17.392   758.000000
# 2323      5.0  Level 3  40:83:1d:69:56:95 2019-12-01 09:23:47.226    29.000000
# 6905      5.0  Level 3  a8:16:d0:9c:16:a5 2019-12-01 09:24:43.080    55.000000
# 6068      5.0  Level 3  10:d0:7a:7c:e0:65 2019-12-01 09:42:14.365  1051.000000
# 1050      5.0  Level 3  bc:98:df:89:bf:8b 2019-12-01 09:47:13.354   298.000000
# 1784      5.0  Level 3  bc:98:df:89:bf:8b 2019-12-01 09:53:55.400   402.000000
# 1799      5.0  Level 3  bc:98:df:89:bf:8b 2019-12-01 09:53:55.401     0.000000
# 5540      5.0  Level 3  bc:98:df:89:bf:8b 2019-12-01 10:21:06.396  1630.000000
# 1801      5.0  Level 3  98:39:8e:7b:5e:7f 2019-12-01 10:25:53.645   287.000000
# 6991      5.0  Level 3  7c:5c:f8:45:a9:f7 2019-12-01 10:27:37.236   103.000000
# 256       5.0  Level 3  f8:87:f1:dd:27:5e 2019-12-01 10:29:31.906   114.000000
# 223       5.0  Level 3  f8:87:f1:dd:27:5e 2019-12-01 10:29:31.907     0.000000
# 3914      5.0  Level 3  70:fd:46:12:6d:ec 2019-12-01 10:31:58.527   146.000000

# %% [markdown]
# Extracted the location of various gates by the flights that depart from them in terminal two ( Google Maps & Aeroporto de galeo website data ) and computed the GeoPy distance between the current outlet and the Gates .

# %%
Location = (-22.815,-43.2445)

# %%
Gate_Delta = (-22.8151,-43.2457)

# %%
Gate_United= (-22.8151,-43.2455)

# %%
Gate_AA= (-22.8148,-43.2449)

# %%
Gate_Emirates= (-22.8141,-43.2453)

# %%
Gate_Lufthansa= (-22.8142,-43.2457)

# %%
Gate_Copa = (-22.8140,-43.2455)

# %%
Gate_AirFrance = (-22.8141,-43.2460)

# %%
Gate_AirArg = (-22.8142,-43.2454)

# %%
Gate_Airitalia = (-22.8142,-43.2460)

# %%
from geopy.distance import vincenty

# %%
df1['dist_DA'] = vincenty(Location,Gate_Delta).meters

# %%
df1['dist_UA'] =vincenty(Location,Gate_United).meters

# %%
df1['dist_AA'] =vincenty(Location,Gate_AA).meters

# %%
df1['dist_EM']= vincenty(Location,Gate_Emirates).meters

# %%
df1['dist_LF']= vincenty(Location,Gate_Lufthansa).meters

# %%
df1['dist_Copa'] = vincenty(Location,Gate_Copa).meters

# %%
df1['dist_AF']  = vincenty(Location,Gate_AirFrance).meters

# %%
df1['dist_AG'] = vincenty(Location,Gate_AirArg).meters

# %%
df1['dist_AI'] = vincenty(Location,Gate_Airitalia).meters

# %% [markdown]
# Appended the geodistances in meters as additional columns in the dataframe

# %%
df1.head(5)
# Out:
#       Ratings    level             MAC-ID  ...     dist_AF     dist_AG     dist_AI
# 3730      5.0  Level 3  1a:1c:0b:df:1d:ad  ...  183.432375  128.006762  177.658651
# 2546      5.0  Level 3  7c:5c:f8:45:2f:72  ...  183.432375  128.006762  177.658651
# 1625      5.0  Level 3  60:1d:91:95:f6:ef  ...  183.432375  128.006762  177.658651
# 2506      5.0  Level 3  7c:5c:f8:45:a9:f7  ...  183.432375  128.006762  177.658651
# 1416      5.0  Level 3  7c:5c:f8:45:2f:72  ...  183.432375  128.006762  177.658651
#
# [5 rows x 14 columns]

# %% [markdown]
# Performed Binning of the data into target risk levels based on stats from the following link:
#
# [AirlineFlightDelays Stats : A Survey](https://stat-or.unc.edu/files/2018/09/Paper3_MSOM_2012_AirlineFlightDelays.pdf)
#
#
# Target Variable recommended risk levels -
# **Encoding Scheme :**
#
# *   Low Risk - 0
# *   Medium Risk - 1
#
#
# *   High Risk -2

# %%
median=df1['Wait-Time'].median()

# %%
percentile_75 = df1['Wait-Time'].quantile(q=0.75)

# %%
percentile_25 = df1['Wait-Time'].quantile(q=0.25)

# %%
df1.shape
# Out:
# (7020, 14)

# %%
df1['Risk-level'] = 0

# %%
df1.loc[ (df1['Wait-Time'] > median) & (df1.Ratings >= 3.0 ),'Risk-level'] = 2

# %%
df1.loc[ (df1['Wait-Time'] <= median) & (df1['Wait-Time'] > percentile_25)  & (df1.Ratings >= 3.0 ),'Risk-level'] = 1

# %%
df1.loc[(df1['Wait-Time'] <= percentile_25 ) & (df1.Ratings >= 3.0 ),'Risk-level'] = 0

# %%
len(df1[df1['Risk-level']==2])
# Out:
# 3501

# %%
df1.shape
# Out:
# (7020, 15)

# %%
df1= df1.drop('Timestamp', 1)

# %%
df1= df1.drop('MAC-ID', 1)
df1= df1.drop('level',1)

# %%
df1.shape
# Out:
# (7020, 12)

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips = df1
ax = sns.boxplot(x=df1['Risk-level'],y=df1['Wait-Time'])
ax.set_ylim([0, 100])
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# (0.0, 100.0)

# %% [markdown]
# Data has now been completely preprocessed and ready for analysis

# %% [markdown]
# Train-test Split Performed : ( 80:20 split taken . 80% for training the model and 20% for testing the model ) . Will use the training set itself to perform 10 fold cross validation for model selection

# %%
data_x= df1.iloc[:,0:11]
data_y =df1.iloc[:,11:12]

# %%
import math
trainVal = math.trunc(df1.shape[0]*.8)
numRows = df1.shape[0]

# %%
train_x = data_x.iloc[0:trainVal,:]
train_y = data_y.iloc[0:trainVal,:]
test_x = data_x.iloc[trainVal:numRows,:]
test_y = data_y.iloc[trainVal:numRows,:]

# %%
from sklearn.utils import shuffle
train_x,train_y = shuffle(train_x,train_y)

# %%
test_x,test_y = shuffle(test_x,test_y)

# %%
test_x.shape
# Out:
# (1404, 11)

# %% [markdown]
# # Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegressionCV 
from sklearn.metrics import roc_curve, auc, confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.multiclass import OneVsRestClassifier

# %%
mdl = LogisticRegressionCV(cv=10)

# %%
mdl.fit(train_x,train_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegressionCV(Cs=10, class_weight=None, cv=10, dual=False,
#                      fit_intercept=True, intercept_scaling=1.0, l1_ratios=None,
#                      max_iter=100, multi_class='auto', n_jobs=None,
#                      penalty='l2', random_state=None, refit=True, scoring=None,
#                      solver='lbfgs', tol=0.0001, verbose=0)

# %%
preds_y=mdl.predict(test_x)

# %%
training_acc = mdl.score(train_x,train_y)
test_acc = mdl.score(test_x,test_y)

# %% [markdown]
# Evaluation Metrics : Accuracy , Precision , Recall , F-1 score and Area under the curve - Reason for selection of these metrics ( Classification problem statement )

# %%
test_acc
# Out:
# 1.0

# %%
from sklearn import metrics
from sklearn.metrics import classification_report

confusion_mat = metrics.confusion_matrix(test_y,preds_y)
report_Logistic=classification_report(test_y,preds_y)

# %%
print(confusion_mat)
# Out:
# [[242   0   0]
#  [  0 400   0]
#  [  0   0 762]]

# %%
print(report_Logistic)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       242
#            1       1.00      1.00      1.00       400
#            2       1.00      1.00      1.00       762
#
#     accuracy                           1.00      1404
#    macro avg       1.00      1.00      1.00      1404
# weighted avg       1.00      1.00      1.00      1404

# %%
classes = [0,1,2]
import numpy as np
import matplotlib.pyplot as plt

# %%
from itertools import cycle
from scipy import interp
from sklearn.preprocessing import label_binarize
def report_multi_class(train_X_norm, train_Y, test_Y, y_predict, y_score):
    lw = 2
    con_matrix = confusion_matrix(test_Y, y_predict)    
    train_Y = label_binarize(train_Y, classes=classes)
    test_Y = label_binarize(test_Y, classes=classes)
    y_predict = label_binarize(y_predict, classes=classes)
    n_classes = train_Y.shape[1]
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(test_Y[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    fpr["micro"], tpr["micro"], _ = roc_curve(test_Y.ravel(), y_score.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    # Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # Finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    plt.figure()
    colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'pink', 'olive', 
                    'brown', 'wheat'])
    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=lw,
                 label='ROC curve of class {0} (area = {1:0.2f})'
                 ''.format(classes[i], roc_auc[i]))
    
    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Some extension of Receiver operating characteristic to multi-class')
    plt.legend(loc="upper left")
    plt.show()
    
    print("Confusion Matrix: \n", con_matrix)

# %%
y_score = mdl.decision_function(test_x)
report_multi_class(train_x, train_y, test_y, preds_y, y_score)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Confusion Matrix:
#  [[242   0   0]
#  [  0 400   0]
#  [  0   0 762]]

# %% [markdown]
# # RBF Kernelized Support vector machine

# %%
from sklearn.svm import SVC
from sklearn import svm

mdl_svm=svm.SVC(kernel='rbf')
mdl_svm.fit(train_x,train_y)
preds_svm=mdl_svm.predict(test_x)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
test_acc_svm = mdl_svm.score(test_x,test_y)

# %% [markdown]
# Evaluation Metrics : Accuracy , precision , recall , F1-score and Area under the curve

# %%
test_acc_svm
# Out:
# 0.938034188034188

# %%
from sklearn import metrics
from sklearn.metrics import classification_report

confusion_mat_svm = metrics.confusion_matrix(test_y,preds_svm)
report_svm=classification_report(test_y,preds_svm)

# %%
print(confusion_mat_svm)
print(report_svm)
# Out:
# [[242   0   0]
#  [ 62 338   0]
#  [  0  25 737]]
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89       242
#            1       0.93      0.84      0.89       400
#            2       1.00      0.97      0.98       762
#
#     accuracy                           0.94      1404
#    macro avg       0.91      0.94      0.92      1404
# weighted avg       0.95      0.94      0.94      1404

# %%
y_score_svm = mdl_svm.decision_function(test_x)
report_multi_class(train_x, train_y, test_y, preds_svm, y_score_svm)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Confusion Matrix:
#  [[242   0   0]
#  [ 62 338   0]
#  [  0  25 737]]

# %% [markdown]
# # Multinomial Naive Bayes Classifier reinforced by one vs all classifier

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier

# %%
mdl2= OneVsRestClassifier(MultinomialNB())

# %%
mdl2.fit(train_x,train_y)
# Out:
# OneVsRestClassifier(estimator=MultinomialNB(alpha=1.0, class_prior=None,
#                                             fit_prior=True),
#                     n_jobs=None)

# %%
pred_y_NB=mdl2.predict(test_x)

# %%
training_acc_NB = mdl2.score(train_x,train_y)
test_acc_NB = mdl2.score(test_x,test_y)

# %% [markdown]
# Evaluation Metrics : Accuracy , precision , recall , F1-score

# %%
test_acc_NB
# Out:
# 0.7022792022792023

# %%
from sklearn import metrics
from sklearn.metrics import classification_report

confusion_mat_NB = metrics.confusion_matrix(test_y,pred_y_NB)
report_NB=classification_report(test_y,pred_y_NB)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(confusion_mat_NB)
# Out:
# [[  0 242   0]
#  [  0 400   0]
#  [  0 176 586]]

# %%
print(report_NB)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       242
#            1       0.49      1.00      0.66       400
#            2       1.00      0.77      0.87       762
#
#     accuracy                           0.70      1404
#    macro avg       0.50      0.59      0.51      1404
# weighted avg       0.68      0.70      0.66      1404

# %% [markdown]
# # K Nearest Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
mdl3=KNeighborsClassifier(n_neighbors=5)

# %%
mdl3.fit(train_x,train_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
preds_KNN=mdl3.predict(test_x)

# %%
training_acc_KNN = mdl3.score(train_x,train_y)
test_acc_KNN = mdl3.score(test_x,test_y)

# %% [markdown]
# Evaluation Metrics : Accuracy ,Precision ,recall and F1-score

# %%
test_acc_KNN
# Out:
# 1.0

# %%
from sklearn import metrics

confusion_mat_KNN = metrics.confusion_matrix(test_y,preds_KNN)
report_KNN=classification_report(test_y,preds_KNN)

# %%
print(confusion_mat_KNN)
print(report_KNN)
# Out:
# [[242   0   0]
#  [  0 400   0]
#  [  0   0 762]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       242
#            1       1.00      1.00      1.00       400
#            2       1.00      1.00      1.00       762
#
#     accuracy                           1.00      1404
#    macro avg       1.00      1.00      1.00      1404
# weighted avg       1.00      1.00      1.00      1404

# %% [markdown]
# # Random forest classifier ( Boosted decision trees )

# %%
from sklearn.ensemble import RandomForestClassifier

mdl_RF = RandomForestClassifier(n_estimators=10,oob_score =True,class_weight='balanced',max_depth=20)
mdl_RF.fit(train_x, train_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py:523: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py:528: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=20, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=True, random_state=None,
#                        verbose=0, warm_start=False)

# %%
preds_RF=mdl_RF.predict(test_x)

# %% [markdown]
# Evaluation Metrics : Out of Bag error estimate , Confusion Matrix

# %%
confusion_mat = confusion_matrix(test_y,preds_RF)
report_RF=classification_report(test_y,preds_RF)
oob_score = mdl_RF.oob_score_
oob_error = 1 - oob_score

print("OOB score: ",oob_score)
print("Out of bag error estimate test data: ",oob_error)
print("Confusion Matrix test data:\n",confusion_mat)
# Out:
# OOB score:  0.9919871794871795
# Out of bag error estimate test data:  0.008012820512820484
# Confusion Matrix test data:
#  [[242   0   0]
#  [  0 400   0]
#  [  0   0 762]]

# %% [markdown]
# After comparing the evaluation metrics of the above built classifiers and the efficiency and complexity of the model in runtime considering that we would be compressing the model as a pickle file to deploy it in the back end of a web application , RBF SVM seem ideal for this scenario

# %%
import pickle

# %%
pickle.dump(mdl_svm, open(output_file,'wb'))

# %%
pickle_loader = pickle.load(open(output_file,'rb'))

# %%
preds_production=pickle_loader.predict(test_x)

# %%
pickle_loader.score(test_x,test_y)
# Out:
# 0.938034188034188

# %%
test_x.head()
# Out:
#       Ratings  Wait-Time     dist_DA  ...     dist_AF     dist_AG     dist_AI
# 3985      5.0      353.0  123.690751  ...  183.432375  128.006762  177.658651
# 6012      5.0       20.0  123.690751  ...  183.432375  128.006762  177.658651
# 1297      5.0       12.0  123.690751  ...  183.432375  128.006762  177.658651
# 6226      5.0      298.0  123.690751  ...  183.432375  128.006762  177.658651
# 6664      5.0        0.0  123.690751  ...  183.432375  128.006762  177.658651
#
# [5 rows x 11 columns]
