# %% [markdown]
# Imported Data for Domino's from Drive

# %%
#=======INPUT: LOCATION LAT/LONG=======#
Location = (-22.8147,-43.2466) 

#=======INPUT: PATH TO DATAFRAME FILE=======#
pandas_file = '/gdrive/Shared drives/INF560/Code/Data Files/Dataframes/data23-Dominos.csv'

#=======OUTPUT FILE PATH=======#
output_file = '/gdrive/Shared drives/INF560/Code/Code Files/pickles/loc23model.pkl'

import pandas as pd
df=pd.read_excel(pandas_file)

# %%
df.head(5)
# Out:
#    Unnamed: 0    0        1                  2                            3
# 0           0  3.2  Level 3  38:80:df:70:d4:83  2019-12-18 18:31:14.389 UTC
# 1           1  3.2  Level 3  04:1b:6d:ee:c7:a6  2019-12-21 17:05:18.955 UTC
# 2           2  3.2  Level 3  fc:64:3a:92:b6:38   2019-12-30 18:33:27.94 UTC
# 3           3  3.2  Level 3  40:30:04:2a:cd:d8  2019-12-16 22:36:44.462 UTC
# 4           4  3.2  Level 3  ca:b3:fc:da:a4:20  2019-12-19 13:24:32.654 UTC

# %%
df = df.drop('Unnamed: 0', 1)

# %%
df
# Out:
#         0        1                  2                            3
# 0     3.2  Level 3  38:80:df:70:d4:83  2019-12-18 18:31:14.389 UTC
# 1     3.2  Level 3  04:1b:6d:ee:c7:a6  2019-12-21 17:05:18.955 UTC
# 2     3.2  Level 3  fc:64:3a:92:b6:38   2019-12-30 18:33:27.94 UTC
# 3     3.2  Level 3  40:30:04:2a:cd:d8  2019-12-16 22:36:44.462 UTC
# 4     3.2  Level 3  ca:b3:fc:da:a4:20  2019-12-19 13:24:32.654 UTC
# ...   ...      ...                ...                          ...
# 4915  4.3  Level 3  44:91:60:c8:39:18  2019-12-03 10:26:52.918 UTC
# 4916  4.3  Level 3  14:96:e5:2e:b3:62  2019-12-23 18:27:06.864 UTC
# 4917  4.3  Level 3  30:cb:f8:30:11:95  2019-12-03 19:39:33.439 UTC
# 4918  4.3  Level 3  04:1b:6d:aa:0f:ee  2019-12-30 13:11:48.594 UTC
# 4919  4.3  Level 3  d0:04:01:01:92:1d  2019-12-04 03:55:10.287 UTC
#
# [4920 rows x 4 columns]

# %%
df.columns = ['Ratings', 'level','MAC-ID','Timestamp']

# %%
df = df[df['Ratings']==4.3]

# %%
df
# Out:
#       Ratings    level             MAC-ID                    Timestamp
# 2460      4.3  Level 3  38:80:df:70:d4:83  2019-12-18 18:31:14.389 UTC
# 2461      4.3  Level 3  04:1b:6d:ee:c7:a6  2019-12-21 17:05:18.955 UTC
# 2462      4.3  Level 3  fc:64:3a:92:b6:38   2019-12-30 18:33:27.94 UTC
# 2463      4.3  Level 3  40:30:04:2a:cd:d8  2019-12-16 22:36:44.462 UTC
# 2464      4.3  Level 3  ca:b3:fc:da:a4:20  2019-12-19 13:24:32.654 UTC
# ...       ...      ...                ...                          ...
# 4915      4.3  Level 3  44:91:60:c8:39:18  2019-12-03 10:26:52.918 UTC
# 4916      4.3  Level 3  14:96:e5:2e:b3:62  2019-12-23 18:27:06.864 UTC
# 4917      4.3  Level 3  30:cb:f8:30:11:95  2019-12-03 19:39:33.439 UTC
# 4918      4.3  Level 3  04:1b:6d:aa:0f:ee  2019-12-30 13:11:48.594 UTC
# 4919      4.3  Level 3  d0:04:01:01:92:1d  2019-12-04 03:55:10.287 UTC
#
# [2460 rows x 4 columns]

# %% [markdown]
# Formatted the Timestamps into dateTime types from string

# %%
df['Timestamp'] = df['Timestamp'].str.replace(r'UTC', '')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head(5)
# Out:
#       Ratings    level             MAC-ID                 Timestamp
# 2460      4.3  Level 3  38:80:df:70:d4:83  2019-12-18 18:31:14.389
# 2461      4.3  Level 3  04:1b:6d:ee:c7:a6  2019-12-21 17:05:18.955
# 2462      4.3  Level 3  fc:64:3a:92:b6:38   2019-12-30 18:33:27.94
# 2463      4.3  Level 3  40:30:04:2a:cd:d8  2019-12-16 22:36:44.462
# 2464      4.3  Level 3  ca:b3:fc:da:a4:20  2019-12-19 13:24:32.654

# %%
df['Timestamp']=pd.to_datetime(df['Timestamp'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1=df

# %%
df1.head(5)
# Out:
#       Ratings    level             MAC-ID               Timestamp
# 2460      4.3  Level 3  38:80:df:70:d4:83 2019-12-18 18:31:14.389
# 2461      4.3  Level 3  04:1b:6d:ee:c7:a6 2019-12-21 17:05:18.955
# 2462      4.3  Level 3  fc:64:3a:92:b6:38 2019-12-30 18:33:27.940
# 2463      4.3  Level 3  40:30:04:2a:cd:d8 2019-12-16 22:36:44.462
# 2464      4.3  Level 3  ca:b3:fc:da:a4:20 2019-12-19 13:24:32.654

# %% [markdown]
# Grouped the data by the MAC ID and sorted by Timestamp . This was done to extract consecutive wait times between 2 timestamps which is indicative of the time duration for which a user has been around this location .

# %%
df1=df1.sort_values('Timestamp', ascending=True)

# %%
df1.head(5)
# Out:
#       Ratings    level             MAC-ID               Timestamp
# 4068      4.3  Level 3  d4:c9:4b:9a:ae:75 2019-12-01 00:06:49.238
# 4046      4.3  Level 3  d4:c9:4b:9a:ae:75 2019-12-01 00:06:49.239
# 3378      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 00:08:43.291
# 4078      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 00:09:18.280
# 2625      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 00:17:52.256

# %% [markdown]
# Computed the wait-time in seconds

# %%
df1['Wait-Time']=df1['Timestamp'].diff().astype('timedelta64[s]')

# %%
df1['Wait-Time'].fillna((df1['Wait-Time'].mean()), inplace=True)

# %%
df1.head(50)
# Out:
#       Ratings    level             MAC-ID               Timestamp    Wait-Time
# 4068      4.3  Level 3  d4:c9:4b:9a:ae:75 2019-12-01 00:06:49.238  1052.790972
# 4046      4.3  Level 3  d4:c9:4b:9a:ae:75 2019-12-01 00:06:49.239     0.000000
# 3378      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 00:08:43.291   114.000000
# 4078      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 00:09:18.280    34.000000
# 2625      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 00:17:52.256   513.000000
# 2553      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 00:18:43.281    51.000000
# 3843      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 00:20:23.473   100.000000
# 4739      4.3  Level 3  48:49:c7:c8:90:b8 2019-12-01 00:41:40.118  1276.000000
# 2910      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 00:45:13.138   213.000000
# 2911      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 00:45:13.139     0.000000
# 2806      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 01:14:13.264  1740.000000
# 4358      4.3  Level 3  ac:0d:1b:e2:dd:12 2019-12-01 02:38:39.274  5066.000000
# 3144      4.3  Level 3  b0:c1:9e:8f:3d:d3 2019-12-01 02:43:03.229   263.000000
# 3134      4.3  Level 3  b0:c1:9e:8f:3d:d3 2019-12-01 02:43:03.233     0.000000
# 2732      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 03:48:53.325  3950.000000
# 3879      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 03:53:26.741   273.000000
# 4396      4.3  Level 3  f4:bf:80:25:4a:8c 2019-12-01 04:04:24.114   657.000000
# 3513      4.3  Level 3  b8:c3:85:2d:0a:76 2019-12-01 04:59:50.114  3326.000000
# 3390      4.3  Level 3  d4:53:83:9a:d9:9c 2019-12-01 05:46:41.320  2811.000000
# 4077      4.3  Level 3  dc:35:f1:ac:a2:36 2019-12-01 05:49:08.226   146.000000
# 3337      4.3  Level 3  fc:42:03:e7:2b:85 2019-12-01 06:04:33.307   925.000000
# 3224      4.3  Level 3  90:73:5a:26:86:d7 2019-12-01 06:36:14.456  1901.000000
# 3199      4.3  Level 3  90:73:5a:26:86:d7 2019-12-01 06:36:14.457     0.000000
# 4362      4.3  Level 3  e4:2b:34:77:6c:63 2019-12-01 06:41:45.946   331.000000
# 3644      4.3  Level 3  b8:27:eb:11:6e:db 2019-12-01 06:47:24.464   338.000000
# 3642      4.3  Level 3  b8:27:eb:11:6e:db 2019-12-01 06:47:24.465     0.000000
# 2882      4.3  Level 3  8c:f1:12:93:54:62 2019-12-01 06:52:38.006   313.000000
# 3328      4.3  Level 3  88:10:8f:24:bc:34 2019-12-01 07:22:47.691  1809.000000
# 3229      4.3  Level 3  88:b4:a6:0e:88:88 2019-12-01 07:23:00.214    12.000000
# 3668      4.3  Level 3  a8:96:75:e1:b3:1a 2019-12-01 07:28:28.654   328.000000
# 3694      4.3  Level 3  a8:96:75:e1:b3:1a 2019-12-01 07:28:28.655     0.000000
# 2783      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 07:43:51.462   922.000000
# 3541      4.3  Level 3  18:01:f1:4e:3e:9e 2019-12-01 07:46:47.521   176.000000
# 4382      4.3  Level 3  d0:c5:f3:39:4b:45 2019-12-01 07:52:15.703   328.000000
# 4416      4.3  Level 3  68:fb:7e:35:0d:7b 2019-12-01 08:33:53.257  2497.000000
# 4234      4.3  Level 3  f0:8a:76:a2:94:c2 2019-12-01 09:11:59.747  2286.000000
# 4313      4.3  Level 3  8c:25:05:65:28:1f 2019-12-01 09:20:48.130   528.000000
# 3165      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 09:33:10.373   742.000000
# 2571      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 09:38:15.736   305.000000
# 2520      4.3  Level 3  70:56:81:ad:3f:d7 2019-12-01 11:29:14.671  6658.000000
# 3872      4.3  Level 3  70:fd:46:cc:01:7c 2019-12-01 11:37:21.031   486.000000
# 2469      4.3  Level 3  48:2c:a0:de:ad:15 2019-12-01 12:03:37.743  1576.000000
# 4481      4.3  Level 3  58:d9:c3:83:f9:3d 2019-12-01 12:05:23.424   105.000000
# 3745      4.3  Level 3  7c:5c:f8:45:42:e1 2019-12-01 12:31:53.274  1589.000000
# 4893      4.3  Level 3  24:18:1d:8c:ac:86 2019-12-01 12:39:10.441   437.000000
# 2503      4.3  Level 3  dc:bf:e9:f3:7d:81 2019-12-01 12:41:26.475   136.000000
# 2499      4.3  Level 3  a8:51:5b:19:20:44 2019-12-01 12:41:29.925     3.000000
# 2603      4.3  Level 3  24:18:1d:8c:ac:86 2019-12-01 12:43:06.122    96.000000
# 2609      4.3  Level 3  24:18:1d:8c:ac:86 2019-12-01 12:43:06.134     0.000000
# 4828      4.3  Level 3  38:80:df:33:74:1c 2019-12-01 12:44:35.135    89.000000

# %% [markdown]
# Extracted the location of various gates by the flights that depart from them in terminal two ( Google Maps & Aeroporto de galeo website data ) and computed the GeoPy distance between the current outlet and the Gates .

# %%
Gate_Delta = (-22.8151,-43.2457)

# %%
Gate_United= (-22.8151,-43.2455)

# %%
Gate_AA= (-22.8148,-43.2449)

# %%
Gate_Emirates= (-22.8141,-43.2453)

# %%
Gate_Lufthansa= (-22.8142,-43.2457)

# %%
Gate_Copa = (-22.8140,-43.2455)

# %%
Gate_AirFrance = (-22.8141,-43.2460)

# %%
Gate_AirArg = (-22.8142,-43.2454)

# %%
Gate_Airitalia = (-22.8142,-43.2460)

# %%
from geopy.distance import vincenty

# %%
df1['dist_DA'] = vincenty(Location,Gate_Delta).meters

# %%
df1['dist_UA'] =vincenty(Location,Gate_United).meters

# %%
df1['dist_AA'] =vincenty(Location,Gate_AA).meters

# %%
df1['dist_EM']= vincenty(Location,Gate_Emirates).meters

# %%
df1['dist_LF']= vincenty(Location,Gate_Lufthansa).meters

# %%
df1['dist_Copa'] = vincenty(Location,Gate_Copa).meters

# %%
df1['dist_AF']  = vincenty(Location,Gate_AirFrance).meters

# %%
df1['dist_AG'] = vincenty(Location,Gate_AirArg).meters

# %%
df1['dist_AI'] = vincenty(Location,Gate_Airitalia).meters

# %% [markdown]
# Appended the geodistances in meters as additional columns in the dataframe

# %%
df1.head(5)
# Out:
#       Ratings    level             MAC-ID  ...    dist_AF     dist_AG    dist_AI
# 4068      4.3  Level 3  d4:c9:4b:9a:ae:75  ...  90.604337  135.065962  82.825964
# 4046      4.3  Level 3  d4:c9:4b:9a:ae:75  ...  90.604337  135.065962  82.825964
# 3378      4.3  Level 3  7c:5c:f8:45:42:e1  ...  90.604337  135.065962  82.825964
# 4078      4.3  Level 3  7c:5c:f8:45:42:e1  ...  90.604337  135.065962  82.825964
# 2625      4.3  Level 3  7c:5c:f8:45:42:e1  ...  90.604337  135.065962  82.825964
#
# [5 rows x 14 columns]

# %% [markdown]
# Performed Binning of the data into target risk levels based on stats from the following link:
#
# [AirlineFlightDelays Stats : A Survey](https://stat-or.unc.edu/files/2018/09/Paper3_MSOM_2012_AirlineFlightDelays.pdf)
#
#
# Target Variable recommended risk levels -
# **Encoding Scheme :**
#
# *   Low Risk - 0
# *   Medium Risk - 1
#
#
# *   High Risk -2

# %%
median=df1['Wait-Time'].median()

# %%
percentile_75 = df1['Wait-Time'].quantile(q=0.75)

# %%
percentile_25 = df1['Wait-Time'].quantile(q=0.25)

# %%
df1.shape
# Out:
# (2460, 14)

# %%
df1['Risk-level'] = 0

# %%
df1.loc[ (df1['Wait-Time'] > median) & (df1.Ratings >= 3.0 ),'Risk-level'] = 2

# %%
df1.loc[ (df1['Wait-Time'] <= median) & (df1['Wait-Time'] > percentile_25)  & (df1.Ratings >= 3.0 ),'Risk-level'] = 1

# %%
df1.loc[(df1['Wait-Time'] <= percentile_25 ) & (df1.Ratings >= 3.0 ),'Risk-level'] = 0

# %%
len(df1[df1['Risk-level']==2])
# Out:
# 1230

# %%
df1.shape
# Out:
# (2460, 15)

# %%
df1= df1.drop('Timestamp', 1)

# %%
df1= df1.drop('MAC-ID', 1)
df1= df1.drop('level',1)

# %%
df1.shape
# Out:
# (2460, 12)

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips = df1
ax = sns.boxplot(x=df1['Risk-level'],y=df1['Wait-Time'])
ax.set_ylim([0, 100])
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# (0.0, 100.0)

# %% [markdown]
# Data has now been completely preprocessed and ready for analysis

# %% [markdown]
# Train-test Split Performed : ( 80:20 split taken . 80% for training the model and 20% for testing the model ) . Will use the training set itself to perform 10 fold cross validation for model selection

# %%
data_x= df1.iloc[:,0:11]
data_y =df1.iloc[:,11:12]

# %%
import math
trainVal = math.trunc(df1.shape[0]*.8)
numRows = df1.shape[0]

# %%
train_x = data_x.iloc[0:trainVal,:]
train_y = data_y.iloc[0:trainVal,:]
test_x = data_x.iloc[trainVal:numRows,:]
test_y = data_y.iloc[trainVal:numRows,:]

# %%
from sklearn.utils import shuffle
train_x,train_y = shuffle(train_x,train_y)

# %%
test_x,test_y = shuffle(test_x,test_y)

# %%
test_x.shape
# Out:
# (492, 11)

# %% [markdown]
# # Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegressionCV 
from sklearn.metrics import roc_curve, auc, confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.multiclass import OneVsRestClassifier

# %%
mdl = LogisticRegressionCV(cv=10)

# %%
mdl.fit(train_x,train_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegressionCV(Cs=10, class_weight=None, cv=10, dual=False,
#                      fit_intercept=True, intercept_scaling=1.0, l1_ratios=None,
#                      max_iter=100, multi_class='auto', n_jobs=None,
#                      penalty='l2', random_state=None, refit=True, scoring=None,
#                      solver='lbfgs', tol=0.0001, verbose=0)

# %%
preds_y=mdl.predict(test_x)

# %%
training_acc = mdl.score(train_x,train_y)
test_acc = mdl.score(test_x,test_y)

# %% [markdown]
# Evaluation Metrics : Accuracy , Precision , Recall , F-1 score and Area under the curve - Reason for selection of these metrics ( Classification problem statement )

# %%
test_acc
# Out:
# 1.0

# %%
from sklearn import metrics
from sklearn.metrics import classification_report

confusion_mat = metrics.confusion_matrix(test_y,preds_y)
report_Logistic=classification_report(test_y,preds_y)

# %%
print(confusion_mat)
# Out:
# [[ 89   0   0]
#  [  0 130   0]
#  [  0   0 273]]

# %%
print(report_Logistic)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        89
#            1       1.00      1.00      1.00       130
#            2       1.00      1.00      1.00       273
#
#     accuracy                           1.00       492
#    macro avg       1.00      1.00      1.00       492
# weighted avg       1.00      1.00      1.00       492

# %%
classes = [0,1,2]
import numpy as np
import matplotlib.pyplot as plt

# %%
from itertools import cycle
from scipy import interp
from sklearn.preprocessing import label_binarize
def report_multi_class(train_X_norm, train_Y, test_Y, y_predict, y_score):
    lw = 2
    con_matrix = confusion_matrix(test_Y, y_predict)    
    train_Y = label_binarize(train_Y, classes=classes)
    test_Y = label_binarize(test_Y, classes=classes)
    y_predict = label_binarize(y_predict, classes=classes)
    n_classes = train_Y.shape[1]
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(test_Y[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    fpr["micro"], tpr["micro"], _ = roc_curve(test_Y.ravel(), y_score.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    # Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # Finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    plt.figure()
    colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'pink', 'olive', 
                    'brown', 'wheat'])
    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=lw,
                 label='ROC curve of class {0} (area = {1:0.2f})'
                 ''.format(classes[i], roc_auc[i]))
    
    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Some extension of Receiver operating characteristic to multi-class')
    plt.legend(loc="upper left")
    plt.show()
    
    print("Confusion Matrix: \n", con_matrix)

# %%
y_score = mdl.decision_function(test_x)
report_multi_class(train_x, train_y, test_y, preds_y, y_score)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Confusion Matrix:
#  [[ 89   0   0]
#  [  0 130   0]
#  [  0   0 273]]

# %% [markdown]
# # RBF Kernelized Support vector machine

# %%
from sklearn.svm import SVC
from sklearn import svm

mdl_svm=svm.SVC(kernel='rbf')
mdl_svm.fit(train_x,train_y)
preds_svm=mdl_svm.predict(test_x)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
test_acc_svm = mdl_svm.score(test_x,test_y)

# %% [markdown]
# Evaluation Metrics : Accuracy , precision , recall , F1-score and Area under the curve

# %%
test_acc_svm
# Out:
# 0.967479674796748

# %%
from sklearn import metrics
from sklearn.metrics import classification_report

confusion_mat_svm = metrics.confusion_matrix(test_y,preds_svm)
report_svm=classification_report(test_y,preds_svm)

# %%
print(confusion_mat_svm)
print(report_svm)
# Out:
# [[ 89   0   0]
#  [ 14 116   0]
#  [  0   2 271]]
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93        89
#            1       0.98      0.89      0.94       130
#            2       1.00      0.99      1.00       273
#
#     accuracy                           0.97       492
#    macro avg       0.95      0.96      0.95       492
# weighted avg       0.97      0.97      0.97       492

# %%
y_score_svm = mdl_svm.decision_function(test_x)
report_multi_class(train_x, train_y, test_y, preds_svm, y_score_svm)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Confusion Matrix:
#  [[ 89   0   0]
#  [ 14 116   0]
#  [  0   2 271]]

# %% [markdown]
# # Multinomial Naive Bayes Classifier reinforced by one vs all classifier

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier

# %%
mdl2= OneVsRestClassifier(MultinomialNB())

# %%
mdl2.fit(train_x,train_y)
# Out:
# OneVsRestClassifier(estimator=MultinomialNB(alpha=1.0, class_prior=None,
#                                             fit_prior=True),
#                     n_jobs=None)

# %%
pred_y_NB=mdl2.predict(test_x)

# %%
training_acc_NB = mdl2.score(train_x,train_y)
test_acc_NB = mdl2.score(test_x,test_y)

# %% [markdown]
# Evaluation Metrics : Accuracy , precision , recall , F1-score

# %%
test_acc_NB
# Out:
# 0.7926829268292683

# %%
from sklearn import metrics
from sklearn.metrics import classification_report

confusion_mat_NB = metrics.confusion_matrix(test_y,pred_y_NB)
report_NB=classification_report(test_y,pred_y_NB)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(confusion_mat_NB)
# Out:
# [[  0  89   0]
#  [  0 130   0]
#  [  0  13 260]]

# %%
print(report_NB)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        89
#            1       0.56      1.00      0.72       130
#            2       1.00      0.95      0.98       273
#
#     accuracy                           0.79       492
#    macro avg       0.52      0.65      0.56       492
# weighted avg       0.70      0.79      0.73       492

# %% [markdown]
# # K Nearest Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
mdl3=KNeighborsClassifier(n_neighbors=5)

# %%
mdl3.fit(train_x,train_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
preds_KNN=mdl3.predict(test_x)

# %%
training_acc_KNN = mdl3.score(train_x,train_y)
test_acc_KNN = mdl3.score(test_x,test_y)

# %% [markdown]
# Evaluation Metrics : Accuracy ,Precision ,recall and F1-score

# %%
test_acc_KNN
# Out:
# 0.9959349593495935

# %%
from sklearn import metrics

confusion_mat_KNN = metrics.confusion_matrix(test_y,preds_KNN)
report_KNN=classification_report(test_y,preds_KNN)

# %%
print(confusion_mat_KNN)
print(report_KNN)
# Out:
# [[ 87   2   0]
#  [  0 130   0]
#  [  0   0 273]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        89
#            1       0.98      1.00      0.99       130
#            2       1.00      1.00      1.00       273
#
#     accuracy                           1.00       492
#    macro avg       0.99      0.99      0.99       492
# weighted avg       1.00      1.00      1.00       492

# %% [markdown]
# # Random forest classifier ( Boosted decision trees )

# %%
from sklearn.ensemble import RandomForestClassifier

mdl_RF = RandomForestClassifier(n_estimators=10,oob_score =True,class_weight='balanced',max_depth=20)
mdl_RF.fit(train_x, train_y)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py:523: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py:528: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=20, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=True, random_state=None,
#                        verbose=0, warm_start=False)

# %%
preds_RF=mdl_RF.predict(test_x)

# %% [markdown]
# Evaluation Metrics : Out of Bag error estimate , Confusion Matrix

# %%
confusion_mat = confusion_matrix(test_y,preds_RF)
report_RF=classification_report(test_y,preds_RF)
oob_score = mdl_RF.oob_score_
oob_error = 1 - oob_score

print("OOB score: ",oob_score)
print("Out of bag error estimate test data: ",oob_error)
print("Confusion Matrix test data:\n",confusion_mat)
# Out:
# OOB score:  0.9969512195121951
# Out of bag error estimate test data:  0.0030487804878048808
# Confusion Matrix test data:
#  [[ 87   2   0]
#  [  0 130   0]
#  [  0   0 273]]

# %% [markdown]
# After comparing the evaluation metrics of the above built classifiers and the efficiency and complexity of the model in runtime considering that we would be compressing the model as a pickle file to deploy it in the back end of a web application , RBF SVM seem ideal for this scenario

# %%
import pickle

# %%
pickle.dump(mdl_svm, open(output_file,'wb'))

# %%
pickle_loader = pickle.load(open(output_file,'rb'))

# %%
preds_production=pickle_loader.predict(test_x)

# %%
pickle_loader.score(test_x,test_y)
# Out:
# 0.967479674796748

# %%
test_x.head()
# Out:
#       Ratings  Wait-Time     dist_DA  ...    dist_AF     dist_AG    dist_AI
# 2771      4.3     1903.0  102.465289  ...  90.604337  135.065962  82.825964
# 4788      4.3     4941.0  102.465289  ...  90.604337  135.065962  82.825964
# 3878      4.3      496.0  102.465289  ...  90.604337  135.065962  82.825964
# 3126      4.3     1108.0  102.465289  ...  90.604337  135.065962  82.825964
# 3863      4.3        0.0  102.465289  ...  90.604337  135.065962  82.825964
#
# [5 rows x 11 columns]
